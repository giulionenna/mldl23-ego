# %%
import pickle
import numpy as np

# %%
path = '/Users/francesco/Desktop/Università/SecondoAnno/MLDL/MLDL_HW/mldl23-ego-master/train_val/D1_train.pkl'
with open(path, 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
#         uid participant_id video_id     narration start_timestamp  \
# 0     12915            P08   P08_01   open fridge     00:00:04.09
# 1     12916            P08   P08_01      get milk     00:00:05.94
# 2     12917            P08   P08_01  close fridge     00:00:07.29
# 3     12918            P08   P08_01      get moka     00:00:10.64
# 4     12919            P08   P08_01   place water     00:00:15.72
# ...     ...            ...      ...           ...             ...
# 1538  15576            P08   P08_28     take bowl     00:00:21.40
# 1539  15577            P08   P08_28   open fridge     00:00:22.08
# 1540  15578            P08   P08_28    place bowl     00:00:23.04
# 1541  15579            P08   P08_28  close fridge     00:00:24.67
# 1542  15581            P08   P08_28    wipe hands     00:00:28.66
#
#      stop_timestamp  start_frame  stop_frame   verb  verb_class
# 0       00:00:05.84          245         350   open           2
# ...

# %% [markdown]
# D1 : 'P08_09', 'P08_10', 'P08_14', 'P08_15', 'P08_16', 'P08_17']
#
# D2: 'P01_11', 'P01_12', 'P01_13', 'P01_14', 'P01_15'
#
# D3: 'P22_01', 'P22_02', 'P22_03', 'P22_04'

# %%
path = '../saved_features/primoTentativo_D1_test.pkl'
with open(path, 'rb') as f:
    data = pickle.load(f)

# %% [markdown]
# # Parte 2

# %%
import hickle
import numpy as np

# %%
path = '/Users/francesco/Desktop/Università/SecondoAnno/MLDL/MLDL_HW/mldl23-ego-master/audio_feat/D1-D1_train_Spec_TSN_.pkl'
with open(path, 'rb') as f:
    data = hickle.load(f)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/hickle/lookup.py:1547: DataRecoveredWarning: loader 'b'!recover!'' missing for 'AttemptRecoverCustom' type object. Data recovered (data)
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/hickle/lookup.py:1523: DataRecoveredWarning: loader 'b'!recover!'' missing for 'AttemptRecoverCustom' type object. Data recovered (data)
#   warnings.warn(

# %%
data["'narration_ids'"].shape
# Out:
# (1543,)

# %%
data["'features'"]["'Spec'"][1]
# Out:
# {'base_type': 'dict_item',
#  'key_base_type': 'str',
#  'key_idx': 0,
#  'key_type': b'\x80\x03cdill._dill\n_load_type\nq\x00X\x03\x00\x00\x00strq\x01\x85q\x02Rq\x03.'}
